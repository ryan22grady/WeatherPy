# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import json
import numpy as np

# Import API key
from config import g_key

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0   Yellowknife      CA  62.4560 -114.3525     66.33       100
# 1        1   Port Alfred      ZA -33.5906   26.8910     53.04        65
# 2        2     Busselton      AU -33.6500  115.3333     49.08        60
# 3        3  Punta Arenas      CL -53.1500  -70.9167     41.11        75
# 4        4        Albany      US  42.6001  -73.9662     79.14        56
#
#    Cloudiness  Wind Speed Current Description
# 0          75        4.00                mist
# 1          73        7.45       broken clouds
# 2          91       16.28     overcast clouds
# 3          37       20.69    scattered clouds
# 4          19        7.09          few clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 70
# What is the maximum temperature you would like for your trip? 88

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID                     City Country      Lat       Lng  Max Temp  \
# 4         4                   Albany      US  42.6001  -73.9662     79.14
# 5         5                    Kapaa      US  22.0752 -159.3190     79.12
# 7         7                   Bethel      US  41.3712  -73.4140     81.16
# 9         9  Saint-Donat-De-Montcalm      CA  46.3187  -74.2219     70.84
# 10       10           Puerto Penasco      MX  31.3167 -113.5333     87.91
# 17       17                 Galesong      ID  -5.3166  119.3661     73.42
# 20       20                     Hilo      US  19.7297 -155.0900     72.25
# 23       23               Guarapuava      BR -25.3953  -51.4581     72.27
# 24       24               San Andres      CO  12.5847  -81.7006     81.07
# 25       25                  Rikitea      PF -23.1203 -134.9692     71.83
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 4         56          19        7.09          few clouds
# 5         81          90        5.01          light rain
# 7         56           3        1.01           clear sky
# 9         40          30        5.06    scattered clouds
# 10        76         100       11.99     overcast clouds
# 17        75          38        5.86    scattered clouds
# 20        94          90        5.75       moderate rain
# 23        27           0        5.17           clear sky
# 24        82          87       21.79     overcast clouds
# 25        75          67       18.19       broken clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                331
# City                   331
# Country                331
# Lat                    331
# Lng                    331
# Max Temp               331
# Humidity               331
# Cloudiness             331
# Wind Speed             331
# Current Description    331
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
#Not applicable

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                        City Country  Max Temp Current Description      Lat  \
# 4                    Albany      US     79.14          few clouds  42.6001
# 5                     Kapaa      US     79.12          light rain  22.0752
# 7                    Bethel      US     81.16           clear sky  41.3712
# 9   Saint-Donat-De-Montcalm      CA     70.84    scattered clouds  46.3187
# 10           Puerto Penasco      MX     87.91     overcast clouds  31.3167
# 17                 Galesong      ID     73.42    scattered clouds  -5.3166
# 20                     Hilo      US     72.25       moderate rain  19.7297
# 23               Guarapuava      BR     72.27           clear sky -25.3953
# 24               San Andres      CO     81.07     overcast clouds  12.5847
# 25                  Rikitea      PF     71.83       broken clouds -23.1203
#
#          Lng Hotel Name
# 4   -73.9662
# 5  -159.3190
# 7   -73.4140
# 9   -74.2219
# 10 -113.5333
# 17  119.3661
# 20 -155.0900
# 23  -51.4581
# 24  -81.7006
# 25 -134.9692

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDR7KKK82_lDetzSBazL8BRcEamdv-5MZHPiMd9rA8AR2S2InxV2D6X80Ta9CnwCcNwMEBXY-ESHc8avpGgiLB0hDx-mvJEox27LVx_Qk8RqPANMpK9WrSegTPFatf2vyEDO3Iu_fTDTGoNaS0H0l9p8TrFhF3j-9KhHxAQFhaZuUW8O3f8rfj-euSCgVNPkcRV9Y_MaYvMWfuCto1zGgEYxFJqJzxgfTkBiBt8ftRuodSI8hJ8bylh9jShwZpTjakNrHuBoJPjHHbekIs1bRc3u84cQhXXFCn_STdLnjB_vW3uxwCUHsbyd-2rXQQDfwECECLsEYZ-ywHtwbnb4XUfQjSMNzklLbp1_bZbPjFevLV7sGU_Q-D8LgwcOjABrWtlgDFEKhKbhyCF2U4lrpbtw2O7a62kC0_MulzXNBGWpTJIzzazyW7_',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291503},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEDZhIRjBdV_JNtnslffAPLgCqhX7ohqVDeZ7eMD5aZBYYqxLGLsJ9seVD9E8DxBKgfoNSKrWC2rffF7T8P2XdBZ_s26OKzdIaZe28UwEyqyqfiYMXq0hrDvWtELPTOvQLqj6imJiG3B4yWCafAhgFxzVO5puJO7d0cPMf6MJBZKp5tt',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 284,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.8595495802915,
#       'lng': 2.347780980291502},
#      'southwest': {'lat': 48.8568516197085, 'lng': 2.345083019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3168,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEAgb2QZT5e2tk08s4MhTftEcd6HAYSy8Itxdj-O8vXDNytjB5AzJuIYHu--KZhn6qs6pmNvaxWvjZ2LMQmcq5r85rUJEgaGFYFWX9t8zYOuRTBCbKQ_T7IBwPDjk5UHPESO6MQAnfXod0wOEH3tH5knhlJEkHh7zXj7FvlzrvONgFEt',
#      'width': 4752}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 561,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.86176813029151,
#       'lng': 2.348251430291502},
#      'southwest': {'lat': 48.85907016970851, 'lng': 2.345553469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 849,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEBheeGiTyUYVDWguaW8wQYrMcSNT04i0_HXJAlWR-bZXtkcpdAhdjjYsI5odwnx1vdPHUFkrBygFn2VQFOaMYjSEjU4fztBwKiYDfgkFTRnF8SExYjMew4IvFtG96bUYcgd0TiRq-b3CsWnbqAnm4ZWea1UcYhbRT8x4q6UpgcKL9kf',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.86205553029149,
#       'lng': 2.347674930291502},
#      'southwest': {'lat': 48.85935756970849, 'lng': 2.344976969708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEA-jhgsFNxizIKONeWCQfsP6mHjwPXtPzX-L84md7B5RFBb6Dl526XuC6JCiSz0r6Gpg2qPop-NfPy08boO8ceCsIJ303tA2IODJdNR7XCv1qqOWRJKR-76uUfZE4TFdId-kdQELvFtGauOm8bdbv6waHFFryGmOqtCowB9LNjszVLm',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2163,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86034799999999, 'lng': 2.344054},
#     'viewport': {'northeast': {'lat': 48.8616503302915,
#       'lng': 2.345521080291502},
#      'southwest': {'lat': 48.8589523697085, 'lng': 2.342823119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uEDtZ_Fg8xxpYiwwORPZbjPL13ranns8bJvp318jyQVWT92UznIpFzCAEQO7JaClKmuBxmIqrqGjsyIQLmEpKFfXFeug2mm5T6lQck41PW4HLx9iXDu1rdh0bY6ibjuqEroYJ7MJWWZpHgn2h-pTvcFichBFjiMhZz_KJyvCL_5G1v9P',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 277,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uEDV5AebOFZziivG7Bul1vYTpRzWi5cYRxDrCkw7Xg-oAqkmVrOl8MFe2z2HfKe-OB8tegZik916ju3oxiN_t4LWGk9vLH8QNxCz7QBbSzfv3fiHFcju2hBK14sAzdf93Ayq2RjG7y67Te9mgEa4HCC3gn0rQPXX-nx94uESQS4vZbZ5',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86634659999999, 'lng': 2.36064},
#     'viewport': {'northeast': {'lat': 48.86774953029149,
#       'lng': 2.361898330291501},
#      'southwest': {'lat': 48.86505156970849, 'lng': 2.359200369708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uEDfM11k0wBnR_kM8Urfu2x9HYZ1-4cuomJ-KfcPui-tWZySmm0cqQUqQtUlireHFTP61NOuOeECdG2NNTPgKQHV-KdeOml__ZGFkOcjtXIFh1uXggnKKEi-CJSV3TMYixtqddRgyi--WoWD2wyZNEiirDo660GjK1KQZcMAJjgvcNdk',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 379,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEDA4c6PG7BbTvvCWaU7g2uArOxPZojHaBK-wfS7nHb1tmXII0M9ZzFMzEO7zQd_ZrIXgUrl2FwnrWyrQ9yFPgFQiJDlZDVgyf98RDy4CA6_rfb48r-W3o2Y2tMr-ZDdpMQT1tsnCrL0gPmTYqZQtiiHqX7Cp4sjrLrOYyrTnazthr0J',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.5,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 500,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110161480967920528437">stefan kebbekus</a>'],
#      'photo_reference': 'Aap_uED4RH7O_H7JkoErWnwQHWVkubNmHUXBwoG59RGAy4CYLDRXsF-Df7AhzBmvEWfONgmpPGpcjgTxIWKsMYQxJvyVnYGtOYuNoTzel7ylwShl7vAH337fO40FfW5AMwv9LZtBEfCG7kw-VGDuwE33sSbWb5z7T55Zi8icKTGHXgPv_GFb',
#      'width': 4000}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 782,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel des Comédies Paris',
#    'permanently_closed': True,
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108479076312462330074">Hotels World Online</a>'],
#      'photo_reference': 'Aap_uEBqmW4_wZxG5hDxDJqEqD_stQIIaWF01WmyG4boMXcgdvW3Gdv1a2j4USP1AmC5-YYdAGeal84gAdaW09LuTyF1NHNphBLVU8zGWjNia0Jr8ZBnBOEumNd19z891icmzz3CCmiYmKfGrfTfcLzNh-2S5hsb3SFEzHOTNu2aBPDkv5NH',
#      'width': 1024}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 194,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEDAsTUkmP2ROq5PLBfKw5kyPqMxlnB2ZkAEM6KFX18EBPcGgp9bUNkBa8S8-FdjXI405VzUEvDZLhbKFPEEd_zXeGQeydI2aOqph02Mkraxk-bZevX2TPG-3nlvM8-S_1rWBWIJ8htNmI2zARKMNSFFtqEj_PZ58JvVD8x5LLftOTqu',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 380,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731394302915,
#       'lng': 2.346067130291502},
#      'southwest': {'lat': 48.8704414697085, 'lng': 2.343369169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106224131803115407650">Marcin Marczak</a>'],
#      'photo_reference': 'Aap_uECkRZemPEEK681h1ByzO61WONZtQ2jKSslwY4Cz8_MrGoB3cjrewbIAua3nC_yoJsYRrnuka-9a4dJ0X5jrIat5tJfbTm4_N028ZxeK-63PikCdEEWea8Mneilk6TFdknK4s_ZYgpIpHYwwDNC9BFoRuZyla_iCStZeqjXQ1CH8KAgd',
#      'width': 3264}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.1,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 353,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.84365908029149,
#       'lng': 2.364711430291502},
#      'southwest': {'lat': 48.8409611197085, 'lng': 2.362013469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'Aap_uEDPUA478Zhp_HO4oCvmM3N9rPYWnsv4dAt9IPBcjJwAUKzKsHeMqIBkIuvbBUqo9YYh80oO3-5lxCAa-HqtBHzH-ymUfGT0-41R7N02LeaSYuH4qh87tvKeNKHgQcK_h2NLwWMuKi34efkXYpUbHivu22VHdY0Pd_L_9m6rtJ4Lg21i',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 433,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.864294, 'lng': 2.3307997},
#     'viewport': {'northeast': {'lat': 48.8655772302915,
#       'lng': 2.332153880291502},
#      'southwest': {'lat': 48.8628792697085, 'lng': 2.329455919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'Aap_uEC4ogjR-Clwd8l3HDnKnzJWRasJ6CNnDfsFs1btXl3Ac7z-zb1jXYywQXC84ReKUW_fxFIRPBIP79ZI43ASMb8GFN3tvziGGUgbuZN7K9YW-lPEOhxqZUPHke5kNG-1WdLuy7a3yLIiOCh5uz-b_2uf-kETrQ_ZQDSDJs2AVl5pq2xz',
#      'width': 600}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1073,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724588802915,
#       'lng': 2.340112930291502},
#      'southwest': {'lat': 48.8697609197085, 'lng': 2.337414969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'Aap_uEDiY5QWiVBEmewd44-O5tIvoQXT_cVhXrQP56ARnPe0l-GSS9f2CRkt2lbbZ7VMPgyXu55cCYjeV1FuUrp1P15STAF8Qz_yPeXMCcwVJHLRpt4vVW1rwhST9A1XlG2NREvnMIYRDPEGogzg42oQHe0cVQYwRJ8FbMy3q1tuetiAUwTs',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.8,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 138,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'Aap_uECnfY3zmlBNNUtHNVxY4fLYC7ZiZYgzRMilwVqxiD8AuQwry0PskMfTZqlid4dzLqUJTcTgqWFCnwxgEwSDoICtYL709V9vmeYJBBIJq_m-ceUHLFJcXVRJ9_xHKdq-lJcSUaklGgv5LTddUYXufXZa7DbjynmCbbItLXEPeCzUjIVc',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 143,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uEAcr10Fusq6vEThy1Vp18fWPQk1KLUOvkrp6As1dchj3tE-b3Olh2DmPTwlVgbBmwwhl9oi1wB7ctpo1mubxXj-_ULjTxvXlDDYZqhrQt6sGqs8FilQXCNVk-j-VpSMpVZEcu085RfjuXBL_roS_w1I9qrqd-vc7KFc4jPxjsuyCv3Z',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 325,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499394, 'lng': 2.3462397},
#     'viewport': {'northeast': {'lat': 48.8512682802915,
#       'lng': 2.347501880291502},
#      'southwest': {'lat': 48.8485703197085, 'lng': 2.344803919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Home Latin',
#    'photos': [{'height': 606,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'Aap_uEDNRy3PrW5xicf8VMSKR7ymNdw7fl_YMFI_OHaBoccc4saCoic9fHs0V3BXU6q1298Zom0g_NpEpMON1BM5-042MELItBZcEp4plivsHM8evoW2Wuss9bcV4MlcLW25WKFpQ7H_qUvBB375ZEiaLDm2xhrC0QDWi6pFMu-5Pz1MBOWi',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.6,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 265,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2174,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uEAobaIqDZ_8aLjEJOwIrWMVKNWORaZA66nhXJijQxlSYKAIEYD3FjIg_fyHC5dw4wzugGmm47xLGzI59bRAzDCRAtlRPIaz6PVOvzKiBukaXZjWqWTrOZNlNrlJ9c7QU5Z0q-BiYwBYRSCbDgYjD2p0M_VnUsEY7QQbGt18ZVt-ZuT3',
#      'width': 1739}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 278,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.85313113029149,
#       'lng': 2.346144730291502},
#      'southwest': {'lat': 48.8504331697085, 'lng': 2.343446769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEAr-Zude9WaGyD0suzJq4pW7jKsvZkVfoaGSPPR5cEU0iuTyM7P21aaUhPuloDiEkUDbQmJP7yKd-O1wo9cV_LaMmnvegS-MJq-3eWNWqttAo3_1i4xEc-SpCQXIbH0HZyCd8ZlFvqsqP11nCVMXF7tRplD92nhp38QneT6juG6lG0h',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
# 6a. Set parameters to search for hotels with 5000 meters.

# 6b. Iterate through the hotel DataFrame.
    # 6c. Get latitude and longitude from DataFrame
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    # Adding the latitude and longitude to location key for the params dictionary.
    params = {
    "radius": 5000,
    "type": "lodging",
    "keyword": "lodging",
    "location": f"{lat},{lng}",
    "key": g_key
}

    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    print(f"Retrieving Results for Index {index}: {city_name}.")
    hotels = requests.get(base_url, params=params).json()
    
    results = hotels["results"]

    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index,"Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Retrieving Results for Index 4: Albany.
# Hotel not found... skipping.
# Retrieving Results for Index 5: Kapaa.
# Closest hotel in Kapaa is KAUAI BEACH HOUSE HOSTEL, LLC.
# Retrieving Results for Index 7: Bethel.
# Closest hotel in Bethel is Days Inn by Wyndham Bethel - Danbury.
# Retrieving Results for Index 9: Saint-Donat-De-Montcalm.
# Closest hotel in Saint-Donat-De-Montcalm is Le Fleuron, Motels & Suites.
# Retrieving Results for Index 10: Puerto Penasco.
# Closest hotel in Puerto Penasco is Peñasco Del Sol Hotel and Conference Center.
# Retrieving Results for Index 17: Galesong.
# Closest hotel in Galesong is Wisata Pantai Bintang Galesong.
# Retrieving Results for Index 20: Hilo.
# Closest hotel in Hilo is Hilo Hawaiian Hotel.
# Retrieving Results for Index 23: Guarapuava.
# Closest hotel in Guarapuava is Hotel Rocha's.
# Retrieving Results for Index 24: San Andres.
# Closest hotel in San Andres is Hotel Casablanca.
# Retrieving Results for Index 25: Rikitea.
# Closest hotel in Rikitea is People ThankYou.
# Retrieving Results for Index 26: Palmer.
# Closest hotel in Palmer is The Trainmaster's Inn.
# Retrieving Results for Index 27: Puerto Ayora.
# Closest hotel in Puerto Ayora is CASA DEL LAGO LODGING HOUSE.
# Retrieving Results for Index 28: San Lawrenz.
# Closest hotel in San Lawrenz is Saint Patrick's Hotel Gozo.
# Retrieving Results for Index 31: Vaini.
# Closest hotel in Vaini is Green Lodge Holiday Homes.
# Retrieving Results for Index 36: Tshikapa.
# Closest hotel in Tshikapa is Etas Majore.
# Retrieving Results for Index 37: Souillac.
# Closest hotel in Souillac is L'Exil Lodges.
# Retrieving Results for Index 39: Hasaki.
# Closest hotel in Hasaki is Inubosaki Kanko Hotel.
# Retrieving Results for Index 40: Khed Brahma.
# Hotel not found... skipping.
# Retrieving Results for Index 41: Bathsheba.
# Closest hotel in Bathsheba is Rest Haven Beach Cottages.
# Retrieving Results for Index 42: Bambous Virieux.
# Hotel not found... skipping.
# Retrieving Results for Index 46: Loiza.
# Closest hotel in Loiza is Malibu Beachfront.
# Retrieving Results for Index 47: Castro.
# Closest hotel in Castro is Pousada Rota Dos Tropeiros.
# Retrieving Results for Index 48: Ponta Do Sol.
# Closest hotel in Ponta Do Sol is Palace of Zinos.
# Retrieving Results for Index 51: Atuona.
# Closest hotel in Atuona is Hôtel Hiva Oa Hanakee Lodge.
# Retrieving Results for Index 54: Poum.
# Hotel not found... skipping.
# Retrieving Results for Index 56: Hithadhoo.
# Closest hotel in Hithadhoo is Pebbles Inn.
# Retrieving Results for Index 57: Kamaishi.
# Closest hotel in Kamaishi is Rikuchu Coast Grand Hotel.
# Retrieving Results for Index 58: Kavieng.
# Closest hotel in Kavieng is Nusa Island Retreat.
# Retrieving Results for Index 59: Jamestown.
# Closest hotel in Jamestown is Chautauqua Harbor Hotel.
# Retrieving Results for Index 60: Gampaha.
# Closest hotel in Gampaha is Wet Water Resort.
# Retrieving Results for Index 62: Katsuura.
# Closest hotel in Katsuura is Splash Guest House.
# Retrieving Results for Index 63: Waingapu.
# Closest hotel in Waingapu is Padadita Beach Hotel.
# Retrieving Results for Index 64: Butaritari.
# Closest hotel in Butaritari is Isles Sunset Lodge.
# Retrieving Results for Index 71: San Ramon.
# Closest hotel in San Ramon is Hyatt House San Ramon.
# Retrieving Results for Index 73: Ntungamo.
# Closest hotel in Ntungamo is The Crested Crane Bwindi Hotel.
# Retrieving Results for Index 75: Puerto Leguizamo.
# Closest hotel in Puerto Leguizamo is la casona de juancho.
# Retrieving Results for Index 81: Asau.
# Closest hotel in Asau is Pensiunea Sophia.
# Retrieving Results for Index 82: Muros.
# Closest hotel in Muros is Hostal SOLYMAR.
# Retrieving Results for Index 85: Georgetown.
# Closest hotel in Georgetown is Eastern & Oriental Hotel, Penang.
# Retrieving Results for Index 86: Penzance.
# Closest hotel in Penzance is The Old Coastguard.
# Retrieving Results for Index 91: Dingle.
# Hotel not found... skipping.
# Retrieving Results for Index 92: Lompoc.
# Closest hotel in Lompoc is Surestay Plus Hotel By Best Western Lompoc.
# Retrieving Results for Index 93: Ribeira Grande.
# Closest hotel in Ribeira Grande is BELO CAMPO.
# Retrieving Results for Index 94: Emba.
# Hotel not found... skipping.
# Retrieving Results for Index 97: Winneba.
# Closest hotel in Winneba is Lord's Hands Guesthouse Hotel.
# Retrieving Results for Index 107: Broome.
# Closest hotel in Broome is Chenango Valley State Park.
# Retrieving Results for Index 113: Sitborice.
# Hotel not found... skipping.
# Retrieving Results for Index 115: Escanaba.
# Closest hotel in Escanaba is House of Ludington.
# Retrieving Results for Index 116: Gwadar.
# Closest hotel in Gwadar is Zaver Pearl Continental Hotel.
# Retrieving Results for Index 117: Kadiri.
# Closest hotel in Kadiri is SRI TAYI GRAND.
# Retrieving Results for Index 118: Komsomolskiy.
# Closest hotel in Komsomolskiy is TANTANA HOTEL FERGANA.
# Retrieving Results for Index 121: Avarua.
# Closest hotel in Avarua is Manea on Muri.
# Retrieving Results for Index 122: Ponta Delgada.
# Closest hotel in Ponta Delgada is Senhora da Rosa, Tradition & Nature Hotel.
# Retrieving Results for Index 123: Samarai.
# Closest hotel in Samarai is Nuli Sapi.
# Retrieving Results for Index 126: Itarema.
# Closest hotel in Itarema is 7 Beaufort Brasil.
# Retrieving Results for Index 128: Mabaruma.
# Closest hotel in Mabaruma is Small's Enterprise.
# Retrieving Results for Index 131: Nishihara.
# Closest hotel in Nishihara is Glory island okinawa Yabusachi Resort.
# Retrieving Results for Index 132: Arraial Do Cabo.
# Closest hotel in Arraial Do Cabo is Orlanova Boutique Hotel.
# Retrieving Results for Index 133: Porto Santo.
# Closest hotel in Porto Santo is Pestana Porto Santo.
# Retrieving Results for Index 134: Gamba.
# Hotel not found... skipping.
# Retrieving Results for Index 136: Vanimo.
# Closest hotel in Vanimo is Sandaun Surf Hotel.
# Retrieving Results for Index 138: Ternate.
# Closest hotel in Ternate is Grand Dafam Bela Ternate.
# Retrieving Results for Index 142: Kukshi.
# Hotel not found... skipping.
# Retrieving Results for Index 145: Benguela.
# Closest hotel in Benguela is Aparthotel Mil Cidades.
# Retrieving Results for Index 146: Pimentel.
# Closest hotel in Pimentel is Hotel Puerto del Sol.
# Retrieving Results for Index 147: Hacari.
# Hotel not found... skipping.
# Retrieving Results for Index 154: Caraguatay.
# Closest hotel in Caraguatay is Apart Hotel Terrazas del Parana.
# Retrieving Results for Index 160: Thompson.
# Closest hotel in Thompson is Best Western Thompson Hotel & Suites.
# Retrieving Results for Index 162: Sarangani.
# Closest hotel in Sarangani is Ballistic Islet.
# Retrieving Results for Index 163: Kalmar.
# Closest hotel in Kalmar is Stekhuset, Kom Snart Igen AB.
# Retrieving Results for Index 164: Prince Albert.
# Closest hotel in Prince Albert is Ramada by Wyndham Prince Albert.
# Retrieving Results for Index 167: Hami.
# Closest hotel in Hami is 7 Days Premium.
# Retrieving Results for Index 170: Wuwei.
# Closest hotel in Wuwei is Jianlong Grand Hotel.
# Retrieving Results for Index 175: Kahului.
# Closest hotel in Kahului is Banana Bungalow Maui Hostel.
# Retrieving Results for Index 176: Panzhihua.
# Closest hotel in Panzhihua is Jinhai New Century Grand Hotel.
# Retrieving Results for Index 177: Dum Duma.
# Hotel not found... skipping.
# Retrieving Results for Index 179: Essex.
# Closest hotel in Essex is The Wilshire Grand Hotel.
# Retrieving Results for Index 181: Oussouye.
# Closest hotel in Oussouye is Campement ALULUM.
# Retrieving Results for Index 182: Mogadishu.
# Closest hotel in Mogadishu is Dolphin Hotel.
# Retrieving Results for Index 183: Yatou.
# Closest hotel in Yatou is Jinyue International Hotel.
# Retrieving Results for Index 185: Lata.
# Hotel not found... skipping.
# Retrieving Results for Index 187: Mamallapuram.
# Closest hotel in Mamallapuram is Flip Flops Beach Shack.
# Retrieving Results for Index 190: Ko Samui.
# Closest hotel in Ko Samui is Four Seasons Resort.
# Retrieving Results for Index 193: Porto Novo.
# Closest hotel in Porto Novo is Rédidence OUADADA.
# Retrieving Results for Index 195: Digha.
# Closest hotel in Digha is Hotel Nest Shankarpur.
# Retrieving Results for Index 201: Sao Joao Da Barra.
# Closest hotel in Sao Joao Da Barra is Pousada Kactus.
# Retrieving Results for Index 203: Hendek.
# Closest hotel in Hendek is Ramada by Wyndham Sakarya Hendek.
# Retrieving Results for Index 205: Baturaja.
# Closest hotel in Baturaja is Hotel Bukit Indah Lestari.
# Retrieving Results for Index 207: Bengkulu.
# Closest hotel in Bengkulu is Grage Hotel Bengkulu.
# Retrieving Results for Index 208: Port Moresby.
# Closest hotel in Port Moresby is Hotel Hideaway.
# Retrieving Results for Index 211: Sorong.
# Closest hotel in Sorong is Vega Hotel Sorong.
# Retrieving Results for Index 213: Lasa.
# Closest hotel in Lasa is Gasthof Hotel Sonne Silandro.
# Retrieving Results for Index 215: Maua.
# Closest hotel in Maua is Hilton Garden Inn Santo André.
# Retrieving Results for Index 219: Madras.
# Closest hotel in Madras is KTDC Rain Drops.
# Retrieving Results for Index 222: Koksovyy.
# Hotel not found... skipping.
# Retrieving Results for Index 223: Xixiang.
# Hotel not found... skipping.
# Retrieving Results for Index 227: Zhangjiakou.
# Closest hotel in Zhangjiakou is HUALUXE Hotels & Resorts - Zhangjiakou.
# Retrieving Results for Index 228: Waw.
# Closest hotel in Waw is Amarula Lodge and Restaurant.
# Retrieving Results for Index 229: Hervey Bay.
# Closest hotel in Hervey Bay is Oaks Hervey Bay Resort and Spa.
# Retrieving Results for Index 230: Mayo.
# Hotel not found... skipping.
# Retrieving Results for Index 232: Sao Filipe.
# Closest hotel in Sao Filipe is La Fora Ecolodge.
# Retrieving Results for Index 234: Santa Rosa.
# Closest hotel in Santa Rosa is One Biñan Place.
# Retrieving Results for Index 238: Mahebourg.
# Closest hotel in Mahebourg is Blue Beryl Guest House.
# Retrieving Results for Index 240: Merauke.
# Hotel not found... skipping.
# Retrieving Results for Index 244: Lagoa.
# Closest hotel in Lagoa is Graciosa Resort - Biosphere Island Hotel.
# Retrieving Results for Index 247: Kavaratti.
# Closest hotel in Kavaratti is Bismillah Hotel And Lodging.
# Retrieving Results for Index 248: Banda Aceh.
# Closest hotel in Banda Aceh is Grand Arabia Hotel.
# Retrieving Results for Index 250: Carmen.
# Closest hotel in Carmen is La Venta Inn Hotel Ciudad del Carmen.
# Retrieving Results for Index 252: Faanui.
# Closest hotel in Faanui is InterContinental Bora Bora Resort Thalasso Spa.
# Retrieving Results for Index 255: Bac Giang.
# Closest hotel in Bac Giang is SOJO HOTEL BAC GIANG.
# Retrieving Results for Index 257: Pombas.
# Closest hotel in Pombas is Santa Barbara.
# Retrieving Results for Index 258: Fuyu.
# Closest hotel in Fuyu is Yawan Impression Business Hotel.
# Retrieving Results for Index 259: Strabychovo.
# Hotel not found... skipping.
# Retrieving Results for Index 260: Chapais.
# Closest hotel in Chapais is Motel Le Routier.
# Retrieving Results for Index 262: Huai Yot.
# Closest hotel in Huai Yot is RuenPhukarn Resort.
# Retrieving Results for Index 268: Manta.
# Closest hotel in Manta is Hotel Vistalmar.
# Retrieving Results for Index 272: Jiangyou.
# Closest hotel in Jiangyou is Lavande Hotel.
# Retrieving Results for Index 273: Kabo.
# Hotel not found... skipping.
# Retrieving Results for Index 274: Nador.
# Closest hotel in Nador is Hotel Marchica Lagoon Resort, Nador Morocco.
# Retrieving Results for Index 275: Naze.
# Closest hotel in Naze is 山羊島ホテル.
# Retrieving Results for Index 276: Acari.
# Closest hotel in Acari is Hospedaje Ximens.
# Retrieving Results for Index 280: Aguimes.
# Closest hotel in Aguimes is Vivienda FRALEMAR Arinaga.
# Retrieving Results for Index 284: Fukue.
# Closest hotel in Fukue is Campana Hotel.
# Retrieving Results for Index 288: Alofi.
# Closest hotel in Alofi is Taloa Heights.
# Retrieving Results for Index 295: Gannan.
# Closest hotel in Gannan is Gannan Hotel.
# Retrieving Results for Index 298: Solnechnyy.
# Closest hotel in Solnechnyy is Dom Otdykha "Pastoral'".
# Retrieving Results for Index 299: Shimoda.
# Closest hotel in Shimoda is KYUKAMURA MINAMI-IZU.
# Retrieving Results for Index 303: Accra.
# Closest hotel in Accra is No 1 Oxford Street Hotel and Suites.
# Retrieving Results for Index 304: Santiago Del Estero.
# Closest hotel in Santiago Del Estero is Finca RG.
# Retrieving Results for Index 305: Lakatoro.
# Closest hotel in Lakatoro is Nawov Freswind Bungalows.
# Retrieving Results for Index 307: Millerovo.
# Closest hotel in Millerovo is Hotel Oasis.
# Retrieving Results for Index 309: Warora.
# Closest hotel in Warora is Babulal Food Plaza & Lodging.
# Retrieving Results for Index 313: Ayr.
# Closest hotel in Ayr is Western House Hotel.
# Retrieving Results for Index 314: Kulhudhuffushi.
# Closest hotel in Kulhudhuffushi is Hondaafushi Island Resort.
# Retrieving Results for Index 316: Vila Franca Do Campo.
# Closest hotel in Vila Franca Do Campo is Vinha d'Areia Beach Hotel.
# Retrieving Results for Index 317: Port Blair.
# Closest hotel in Port Blair is KEVINS BED & BREAKFAST.
# Retrieving Results for Index 319: Pau.
# Closest hotel in Pau is O'jardin.
# Retrieving Results for Index 320: Victoria.
# Closest hotel in Victoria is K11 ARTUS.
# Retrieving Results for Index 322: Abeche.
# Closest hotel in Abeche is Hôtel kinpeski.
# Retrieving Results for Index 323: La Rioja.
# Hotel not found... skipping.
# Retrieving Results for Index 324: Sambava.
# Closest hotel in Sambava is Hôtel Las Palmas.
# Retrieving Results for Index 325: Monrovia.
# Closest hotel in Monrovia is Atlantis Beach Hotel.
# Retrieving Results for Index 326: Karratha.
# Closest hotel in Karratha is Aspen Karratha Village.
# Retrieving Results for Index 327: Scarisoara.
# Hotel not found... skipping.
# Retrieving Results for Index 328: Kalmunai.
# Closest hotel in Kalmunai is Villa LUXEZ.
# Retrieving Results for Index 329: Gizo.
# Closest hotel in Gizo is Imagination Island.
# Retrieving Results for Index 330: Surt.
# Closest hotel in Surt is Al- Waffaa Hotel.
# Retrieving Results for Index 331: Bonfim.
# Hotel not found... skipping.
# Retrieving Results for Index 332: Zhezkazgan.
# Closest hotel in Zhezkazgan is Cosmos.
# Retrieving Results for Index 333: Los Llanos De Aridane.
# Closest hotel in Los Llanos De Aridane is Hotel Hacienda de Abajo.
# Retrieving Results for Index 335: Mae Sai.
# Closest hotel in Mae Sai is Sailomjoy, The Boutique Hostel.
# Retrieving Results for Index 336: Kieta.
# Hotel not found... skipping.
# Retrieving Results for Index 337: Orica.
# Closest hotel in Orica is Casa de Yeimy Viera.
# Retrieving Results for Index 339: Harper.
# Closest hotel in Harper is Grands' Guesthouse.
# Retrieving Results for Index 340: Nicoya.
# Closest hotel in Nicoya is Terra Nostra Jungle House.
# Retrieving Results for Index 344: Ambunti.
# Closest hotel in Ambunti is Ambunti Lodge.
# Retrieving Results for Index 345: Touros.
# Closest hotel in Touros is Hotel Vila Gale Touros.
# Retrieving Results for Index 346: Mbanza-Ngungu.
# Closest hotel in Mbanza-Ngungu is Hotel Les Cascades.
# Retrieving Results for Index 349: Anqing.
# Closest hotel in Anqing is Nanxiang Barony Hotel.
# Retrieving Results for Index 352: Salmo.
# Closest hotel in Salmo is Reno Motel.
# Retrieving Results for Index 353: Mamlyutka.
# Hotel not found... skipping.
# Retrieving Results for Index 354: Kisangani.
# Closest hotel in Kisangani is Les Chalets.
# Retrieving Results for Index 355: Horsham.
# Closest hotel in Horsham is Fullers Cottage.
# Retrieving Results for Index 358: Malakal.
# Closest hotel in Malakal is Nile Palace Hotel.
# Retrieving Results for Index 361: Davila.
# Closest hotel in Davila is Blue Ridge Beach Resort.
# Retrieving Results for Index 362: Shingu.
# Closest hotel in Shingu is くまの蔵inn.
# Retrieving Results for Index 363: Sechura.
# Closest hotel in Sechura is Hotel Loma Dorada.
# Retrieving Results for Index 364: Nodeland.
# Hotel not found... skipping.
# Retrieving Results for Index 365: Labuhan.
# Hotel not found... skipping.
# Retrieving Results for Index 368: Cumpas.
# Closest hotel in Cumpas is Hotel La Palma.
# Retrieving Results for Index 369: Chato.
# Closest hotel in Chato is Roda Lodge.
# Retrieving Results for Index 370: Westport.
# Closest hotel in Westport is The Inn at Longshore by OnTheMarc.
# Retrieving Results for Index 371: Tura.
# Closest hotel in Tura is Hotel Polo Orchid.
# Retrieving Results for Index 372: Ambulu.
# Closest hotel in Ambulu is Hotel Ambulu Jember.
# Retrieving Results for Index 373: Manthani.
# Hotel not found... skipping.
# Retrieving Results for Index 374: Kayankulam.
# Closest hotel in Kayankulam is Hotel Kalai.
# Retrieving Results for Index 375: Mlonggo.
# Closest hotel in Mlonggo is Coconut Lodge.
# Retrieving Results for Index 376: Kloulklubed.
# Closest hotel in Kloulklubed is The Adventures Inn-Peleliu.
# Retrieving Results for Index 382: Buala.
# Closest hotel in Buala is Diocese Of Ysabel Resthouse.
# Retrieving Results for Index 383: Kutum.
# Closest hotel in Kutum is Dibbo areaمنطقة دبو.
# Retrieving Results for Index 384: Maceio.
# Closest hotel in Maceio is Jatiúca Hotel & Resort.
# Retrieving Results for Index 386: Dinguiraye.
# Hotel not found... skipping.
# Retrieving Results for Index 388: Cabedelo.
# Closest hotel in Cabedelo is Hotel Almagre.
# Retrieving Results for Index 389: Veraval.
# Closest hotel in Veraval is Hotel Somnath Sagar.
# Retrieving Results for Index 390: Port Keats.
# Closest hotel in Port Keats is TDC Village (Hundred Man Camp).
# Retrieving Results for Index 391: Yumen.
# Hotel not found... skipping.
# Retrieving Results for Index 393: Shangrao.
# Closest hotel in Shangrao is Wanda Realm Shangrao.
# Retrieving Results for Index 394: Port-Gentil.
# Closest hotel in Port-Gentil is Hotel du Parc.
# Retrieving Results for Index 395: Alugan.
# Closest hotel in Alugan is JM Lodge.
# Retrieving Results for Index 397: Kranjska Gora.
# Closest hotel in Kranjska Gora is Hotel Kompas.
# Retrieving Results for Index 398: Jiuquan.
# Closest hotel in Jiuquan is Jiuquan Hotel.
# Retrieving Results for Index 403: Quang Ngai.
# Closest hotel in Quang Ngai is HANA RIVERSIDE VILLA.
# Retrieving Results for Index 406: Roma.
# Closest hotel in Roma is Oak & Ivy Bed and Breakfast.
# Retrieving Results for Index 408: Astorga.
# Closest hotel in Astorga is Astorga Park Hotel.
# Retrieving Results for Index 409: Biak.
# Hotel not found... skipping.
# Retrieving Results for Index 415: Hambantota.
# Hotel not found... skipping.
# Retrieving Results for Index 416: Tucuman.
# Closest hotel in Tucuman is Hotel Tucumán Center - Suites & Business.
# Retrieving Results for Index 419: Dicabisagan.
# Closest hotel in Dicabisagan is Nancy Montanes Bernardo.
# Retrieving Results for Index 420: Augusto Correa.
# Closest hotel in Augusto Correa is Hotel Urumajo.
# Retrieving Results for Index 423: Banjar.
# Closest hotel in Banjar is Villa Oscar.
# Retrieving Results for Index 424: Marivan.
# Closest hotel in Marivan is Castle Suites.
# Retrieving Results for Index 428: Clyde.
# Closest hotel in Clyde is Red Roof Inn Clyde.
# Retrieving Results for Index 430: Kirakira.
# Closest hotel in Kirakira is Sea view Accomodation.
# Retrieving Results for Index 433: El Tigre.
# Closest hotel in El Tigre is Hotel Gemstone Inn.
# Retrieving Results for Index 434: Portland.
# Closest hotel in Portland is Tiny Digs Hotel Portland.
# Retrieving Results for Index 435: Palasa.
# Closest hotel in Palasa is Sri Balaji lodge.
# Retrieving Results for Index 436: Quatre Cocos.
# Closest hotel in Quatre Cocos is Long Beach Mauritius.
# Retrieving Results for Index 437: Vila Velha.
# Closest hotel in Vila Velha is Pousada Convento da Penha.
# Retrieving Results for Index 439: Fuyang.
# Closest hotel in Fuyang is Fuyang Wanda Realm Hotel.
# Retrieving Results for Index 440: Cockburn Town.
# Closest hotel in Cockburn Town is Osprey Beach Hotel.
# Retrieving Results for Index 441: Gualaquiza.
# Closest hotel in Gualaquiza is Hostal El Paraiso.
# Retrieving Results for Index 442: Barzas.
# Hotel not found... skipping.
# Retrieving Results for Index 443: Lucea.
# Closest hotel in Lucea is Grand Palladium Jamaica Resort & Spa.
# Retrieving Results for Index 447: San Cristobal.
# Closest hotel in San Cristobal is Posada Turística Terrazas Del Viento C.A..
# Retrieving Results for Index 448: Hirara.
# Closest hotel in Hirara is かたあきの里.
# Retrieving Results for Index 449: Smidovich.
# Closest hotel in Smidovich is Gostinnitsa.
# Retrieving Results for Index 450: Kizukuri.
# Closest hotel in Kizukuri is Hotel Sunroute Goshogawara.
# Retrieving Results for Index 455: Praia Da Vitoria.
# Closest hotel in Praia Da Vitoria is Atlântida Mar Hotel.
# Retrieving Results for Index 456: Mahibadhoo.
# Closest hotel in Mahibadhoo is Hudhuveli Maldives.
# Retrieving Results for Index 457: Bambanglipuro.
# Closest hotel in Bambanglipuro is Puri Brata.
# Retrieving Results for Index 463: Huitzo.
# Hotel not found... skipping.
# Retrieving Results for Index 467: Burlington.
# Hotel not found... skipping.
# Retrieving Results for Index 476: Omboue.
# Closest hotel in Omboue is Hôtel Georges Faustin Aurat.
# Retrieving Results for Index 477: Boueni.
# Closest hotel in Boueni is LE CHISSIOUA.
# Retrieving Results for Index 484: Nevsehir.
# Hotel not found... skipping.
# Retrieving Results for Index 485: Bzenec.
# Closest hotel in Bzenec is Hotel Lidový dům.
# Retrieving Results for Index 486: Flin Flon.
# Closest hotel in Flin Flon is Prospector Inn.
# Retrieving Results for Index 488: Craig.
# Closest hotel in Craig is Elk Run Inn.
# Retrieving Results for Index 489: Novoagansk.
# Hotel not found... skipping.
# Retrieving Results for Index 491: Dongsheng.
# Closest hotel in Dongsheng is Crowne Plaza Ordos.
# Retrieving Results for Index 493: Peniche.
# Closest hotel in Peniche is Surfers Lodge Peniche.
# Retrieving Results for Index 494: Sabang.
# Closest hotel in Sabang is RedDoorz Syariah @ Sumur Tiga Beach Sabang.
# Retrieving Results for Index 498: Altus.
# Closest hotel in Altus is Days Inn by Wyndham Altus.
# Retrieving Results for Index 499: Eregli.
# Closest hotel in Eregli is Mirel Hotel.
# Retrieving Results for Index 500: Srandakan.
# Hotel not found... skipping.
# Retrieving Results for Index 501: Katobu.
# Closest hotel in Katobu is La Ode Husein.
# Retrieving Results for Index 503: Sola.
# Hotel not found... skipping.
# Retrieving Results for Index 504: Praia.
# Closest hotel in Praia is Hotel Santiago.
# Retrieving Results for Index 511: Robertsport.
# Closest hotel in Robertsport is Nana's Lodge.
# Retrieving Results for Index 512: Keningau.
# Closest hotel in Keningau is Sento Hotel.
# Retrieving Results for Index 513: Axim.
# Closest hotel in Axim is Ankobra Beach.
# Retrieving Results for Index 514: Marsh Harbour.
# Closest hotel in Marsh Harbour is Abaco Beach Resort.
# Retrieving Results for Index 515: Imbituba.
# Closest hotel in Imbituba is Praia Hotel Imbituba.
# Retrieving Results for Index 516: Skeldon.
# Closest hotel in Skeldon is Classic International Hotel & Suites.
# Retrieving Results for Index 517: Elbistan.
# Closest hotel in Elbistan is Grand Elbistan Park Hotel.
# Retrieving Results for Index 518: Kapoeta.
# Closest hotel in Kapoeta is Kuleu Hotel.
# Retrieving Results for Index 521: Severnyy.
# Closest hotel in Severnyy is Hotel VOYAGE.
# Retrieving Results for Index 522: Vao.
# Closest hotel in Vao is OURE TERA beach resort.
# Retrieving Results for Index 523: Norfolk.
# Hotel not found... skipping.
# Retrieving Results for Index 524: La Primavera.
# Closest hotel in La Primavera is Restaurante Sol del Llano.
# Retrieving Results for Index 525: Grand-Lahou.
# Closest hotel in Grand-Lahou is Hotel Beatitude de Grand Lahou.
# Retrieving Results for Index 526: Svetlyy.
# Hotel not found... skipping.
# Retrieving Results for Index 528: Yangambi.
# Closest hotel in Yangambi is Club Yangambi.
# Retrieving Results for Index 531: Ibanda.
# Closest hotel in Ibanda is La Residencia Apartment.
# Retrieving Results for Index 532: Kidodi.
# Hotel not found... skipping.
# Retrieving Results for Index 533: Surab.
# Closest hotel in Surab is Muslim Rent Rooms.
# Retrieving Results for Index 535: Padang.
# Closest hotel in Padang is Air Manis Hill Residence.
# Retrieving Results for Index 537: Kapit.
# Closest hotel in Kapit is Hotel Meligai Kapit.
# Retrieving Results for Index 539: Narasannapeta.
# Closest hotel in Narasannapeta is SPR Grand Hotel.
# Retrieving Results for Index 540: Khasan.
# Hotel not found... skipping.
# Retrieving Results for Index 541: Half Moon Bay.
# Closest hotel in Half Moon Bay is Beach House - Half Moon Bay.
# Retrieving Results for Index 542: Mangrol.
# Hotel not found... skipping.
# Retrieving Results for Index 543: Cravo Norte.
# Closest hotel in Cravo Norte is Hostal hopedaje Sunem.
# Retrieving Results for Index 545: Finschhafen.
# Closest hotel in Finschhafen is Cossam Guest House.
# Retrieving Results for Index 551: Boizenburg.
# Closest hotel in Boizenburg is Jagdschloesschen Schwartow.
# Retrieving Results for Index 552: Marsa Matruh.
# Closest hotel in Marsa Matruh is Arous El Bahr Hotel.
# Retrieving Results for Index 556: Ilyich.
# Closest hotel in Ilyich is Aul Madeniyet.
# Retrieving Results for Index 557: Nalvo.
# Hotel not found... skipping.
# Retrieving Results for Index 558: Krasnoselkup.
# Closest hotel in Krasnoselkup is Krasnosel'kupnefteprodukt.
# Retrieving Results for Index 559: Moosomin.
# Closest hotel in Moosomin is Motel 6.
# Retrieving Results for Index 562: Bundaberg.
# Closest hotel in Bundaberg is Best Western Bundaberg City Motor Inn.
# Retrieving Results for Index 563: Aktau.
# Closest hotel in Aktau is Caspian Riviera Grand Palace Hotel.
# Retrieving Results for Index 566: Bara.
# Hotel not found... skipping.
# Retrieving Results for Index 567: Msanga.
# Hotel not found... skipping.
# Retrieving Results for Index 568: Tandil.
# Closest hotel in Tandil is Brisas Serranas.
# Retrieving Results for Index 569: Nuevo Progreso.
# Hotel not found... skipping.
# Retrieving Results for Index 570: Voi.
# Closest hotel in Voi is Voi Wildlife Lodge.
# Retrieving Results for Index 571: Mersing.
# Closest hotel in Mersing is Hard Rock VIP Guest House - Mersing.
# Retrieving Results for Index 573: Najran.
# Hotel not found... skipping.
# Retrieving Results for Index 574: Tabuk.
# Closest hotel in Tabuk is Grand Zion Garden Resort Hotel.
# Retrieving Results for Index 575: Zwedru.
# Closest hotel in Zwedru is B and P Guest House.
# Retrieving Results for Index 576: Sokoto.
# Closest hotel in Sokoto is Grand Ibro Hotel.
# Retrieving Results for Index 578: Naqadeh.
# Closest hotel in Naqadeh is MOALLEM HOTEL.
# Retrieving Results for Index 579: Uvira.
# Hotel not found... skipping.
# Retrieving Results for Index 582: Lorengau.
# Closest hotel in Lorengau is Tharapiyap Lodge.
# Retrieving Results for Index 583: Marica.
# Closest hotel in Marica is Pousada Bela Vista Maricá.
# Retrieving Results for Index 585: Pandan.
# Closest hotel in Pandan is Bahay Ni Kuya Romel.
# Retrieving Results for Index 589: North Bend.
# Closest hotel in North Bend is The Mill Casino • Hotel & RV Park.
# Retrieving Results for Index 592: Northam.
# Closest hotel in Northam is Tarka Trail Camping.
# Retrieving Results for Index 593: San Carlos.
# Closest hotel in San Carlos is Hotel Central.
# Retrieving Results for Index 594: Glendive.
# Closest hotel in Glendive is Astoria Hotel.
# Retrieving Results for Index 599: Kudahuvadhoo.
# Closest hotel in Kudahuvadhoo is Hotel Riu Atoll.
# Retrieving Results for Index 606: Matara.
# Closest hotel in Matara is Villa Polhena.
# Retrieving Results for Index 607: Kropotkin.
# Closest hotel in Kropotkin is Гостиница "НОЙ".
# Retrieving Results for Index 611: Sakaiminato.
# Closest hotel in Sakaiminato is Traveller's Cabin Tottori Sakaiminato EN.
# Retrieving Results for Index 612: La Salle.
# Closest hotel in La Salle is Best Western Oglesby Inn.
# Retrieving Results for Index 613: Ratnagiri.
# Closest hotel in Ratnagiri is The Blue View Villas.
# Retrieving Results for Index 615: Isla Mujeres.
# Closest hotel in Isla Mujeres is Hotel Playa La Media Luna.
# Retrieving Results for Index 618: Fare.
# Closest hotel in Fare is Maitai Lapita Village Huahine.
# Retrieving Results for Index 619: Arona.
# Closest hotel in Arona is Hotel Jardín Tropical.
# Retrieving Results for Index 622: Ferme-Neuve.
# Closest hotel in Ferme-Neuve is Pourvoirie Club Fontbrune Ltee.
# Retrieving Results for Index 623: Mandera.
# Closest hotel in Mandera is Granada hotel Mandera.
# Retrieving Results for Index 624: Thinadhoo.
# Hotel not found... skipping.
# Retrieving Results for Index 626: Natal.
# Closest hotel in Natal is eSuites VILA DO MAR Natal.
# Retrieving Results for Index 630: Karanja.
# Closest hotel in Karanja is Gurukrupa Hotel and Restaurant.
# Retrieving Results for Index 631: Alyangula.
# Closest hotel in Alyangula is SRA A Block.
# Retrieving Results for Index 633: Kupang.
# Closest hotel in Kupang is RedDoorz @ Ketapang Satu Beach Kupang.
# Retrieving Results for Index 642: Whithorn.
# Hotel not found... skipping.
# Retrieving Results for Index 644: San Policarpo.
# Closest hotel in San Policarpo is JM Lodge.
# Retrieving Results for Index 645: Chai Badan.
# Closest hotel in Chai Badan is Narai Grand Hotel.
# Retrieving Results for Index 648: Mayumba.
# Closest hotel in Mayumba is Résidence Hoteliere Matalila.
# Retrieving Results for Index 649: Ardmore.
# Closest hotel in Ardmore is Hampton Inn & Suites Ardmore.
# Retrieving Results for Index 650: Ouadda.
# Hotel not found... skipping.
# Retrieving Results for Index 651: Palauig.
# Closest hotel in Palauig is Blue Spruce Beach Resort.
# Retrieving Results for Index 652: Portales.
# Closest hotel in Portales is Best Western Plus Portales Inn.
# Retrieving Results for Index 654: Ciudad Valles.
# Closest hotel in Ciudad Valles is HOSTAL CASA HUASTECA.
# Retrieving Results for Index 655: Usak.
# Hotel not found... skipping.
# Retrieving Results for Index 656: Eydhafushi.
# Closest hotel in Eydhafushi is Madi Finolhu Guest House.
# Retrieving Results for Index 659: Lasem.
# Hotel not found... skipping.
# Retrieving Results for Index 660: Portage.
# Hotel not found... skipping.
# Retrieving Results for Index 661: Santa Barbara.
# Hotel not found... skipping.
# Retrieving Results for Index 663: Tulsipur.
# Hotel not found... skipping.
# Retrieving Results for Index 664: Bonthe.
# Closest hotel in Bonthe is Council Guesthouse.
# Retrieving Results for Index 665: Taiobeiras.
# Closest hotel in Taiobeiras is Pousada Village.
# Retrieving Results for Index 666: Izazi.
# Closest hotel in Izazi is Amoni Guest House.
# Retrieving Results for Index 668: Morales.
# Hotel not found... skipping.
# Retrieving Results for Index 671: Stephenville.
# Closest hotel in Stephenville is Hampton Inn & Suites Stephenville.
# Retrieving Results for Index 672: Guarapari.
# Closest hotel in Guarapari is Hotel Porto do Sol.
# Retrieving Results for Index 674: Braintree.
# Hotel not found... skipping.
# Retrieving Results for Index 676: Atbasar.
# Closest hotel in Atbasar is Atbasar Ulitsa Istochnaya.
# Retrieving Results for Index 677: Cozumel.
# Closest hotel in Cozumel is El Cozumeleño Beach Resort.

# %%
hotel_df
# Out:
#                         City Country  Max Temp Current Description      Lat  \
# 4                     Albany      US     79.14          few clouds  42.6001
# 5                      Kapaa      US     79.12          light rain  22.0752
# 7                     Bethel      US     81.16           clear sky  41.3712
# 9    Saint-Donat-De-Montcalm      CA     70.84    scattered clouds  46.3187
# 10            Puerto Penasco      MX     87.91     overcast clouds  31.3167
# ..                       ...     ...       ...                 ...      ...
# 671             Stephenville      US     87.89       broken clouds  32.2207
# 672                Guarapari      BR     75.90       broken clouds -20.6667
# 674                Braintree      GB     70.30    scattered clouds  51.8782
# 676                  Atbasar      KZ     75.43           clear sky  51.8000
# 677                  Cozumel      MX     87.87       broken clouds  20.5083
#
#           Lng                                   Hotel Name
# 4    -73.9662
# 5   -159.3190                KAUAI BEACH HOUSE HOSTEL, LLC
# 7    -73.4140         Days Inn by Wyndham Bethel - Danbury
# 9    -74.2219                  Le Fleuron, Motels & Suites
# 10  -113.5333  Peñasco Del Sol Hotel and Conference Center
# ..        ...                                          ...
# 671  -98.2023            Hampton Inn & Suites Stephenville
# 672  -40.4975                           Hotel Porto do Sol
# 674    0.5529
# 676   68.3333                    Atbasar Ulitsa Istochnaya
# 677  -86.9458                   El Cozumeleño Beach Resort
#
# [331 rows x 7 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.replace('', np.nan, inplace=True)
hotel_df.dropna(subset=["Hotel Name"], inplace=True)

# %%
hotel_df
# Out:
#                         City Country  Max Temp Current Description      Lat  \
# 5                      Kapaa      US     79.12          light rain  22.0752
# 7                     Bethel      US     81.16           clear sky  41.3712
# 9    Saint-Donat-De-Montcalm      CA     70.84    scattered clouds  46.3187
# 10            Puerto Penasco      MX     87.91     overcast clouds  31.3167
# 17                  Galesong      ID     73.42    scattered clouds  -5.3166
# ..                       ...     ...       ...                 ...      ...
# 666                    Izazi      TZ     73.96       broken clouds  -7.2000
# 671             Stephenville      US     87.89       broken clouds  32.2207
# 672                Guarapari      BR     75.90       broken clouds -20.6667
# 676                  Atbasar      KZ     75.43           clear sky  51.8000
# 677                  Cozumel      MX     87.87       broken clouds  20.5083
#
#           Lng                                   Hotel Name
# 5   -159.3190                KAUAI BEACH HOUSE HOSTEL, LLC
# 7    -73.4140         Days Inn by Wyndham Bethel - Danbury
# 9    -74.2219                  Le Fleuron, Motels & Suites
# 10  -113.5333  Peñasco Del Sol Hotel and Conference Center
# 17   119.3661               Wisata Pantai Bintang Galesong
# ..        ...                                          ...
# 666   35.7333                            Amoni Guest House
# 671  -98.2023            Hampton Inn & Suites Stephenville
# 672  -40.4975                           Hotel Porto do Sol
# 676   68.3333                    Atbasar Ulitsa Istochnaya
# 677  -86.9458                   El Cozumeleño Beach Resort
#
# [273 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_Vacation.csv"
# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}</dd>
</dl>
"""

# %%
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]
new_hotel_df = locations

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
